# %% [markdown]
# # Display initials.py
# This notebook prints the contents of `initials.py`. Run the code cell below to see the file output.

# %%
from pathlib import Path
p = Path('initials.py')
print(p.read_text())
